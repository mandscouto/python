# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/mandscouto/Downloads/StudentsPerformance.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head() #Exibe as 5 primeiras linhas
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail() #Exibe as 5 últimas linhas
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.shape #Quantidade de linhas e colunas
# Out:
# (1000, 8)

# %%
df.columns #Array com o nome de todas as colunas
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.duplicated().sum() #Quantidade de linhas duplicadas
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isna().sum() #Verifica a existência de NaN em cada coluna
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe() #Sumário estatístico
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.describe(include = 'all') #Sumário estatísticos - inclusive para as variáveis categóricas
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# count     1000           1000                        1000      1000
# unique       2              5                           6         2
# top     female        group C                some college  standard
# freq       518            319                         226       645
# mean       NaN            NaN                         NaN       NaN
# std        NaN            NaN                         NaN       NaN
# min        NaN            NaN                         NaN       NaN
# 25%        NaN            NaN                         NaN       NaN
# 50%        NaN            NaN                         NaN       NaN
# 75%        NaN            NaN                         NaN       NaN
# max        NaN            NaN                         NaN       NaN
#
#        test preparation course  math score  reading score  writing score
# count                     1000  1000.00000    1000.000000    1000.000000
# ...

# %%
df.nunique() #Quantidade de valores únicos em cada coluna
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df['parental level of education'].unique() #Exibindo valores únicos da coluna parental level of education
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df.gender.value_counts() #Contagem de quantas vezes cada gênero
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
provas = ['math score', 'reading score', 'writing score']

# %%
#Ordenação do dataset

df = df.sort_values(by = provas, ascending = False)\
.reset_index(drop = True)

# %%
#Criar coluna com a média das provas

df['mean'] = df[provas].mean(axis = 1)

# %%
#Consulta - homens sem curso preparatório e nota em matemática é igual ou superior à 70

df.query('(gender == "male") & (`test preparation course` == "none") & (`math score` >= 70)')
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 15    male        group C          associate's degree      standard
# 17    male        group E                some college      standard
# 23    male        group D             master's degree      standard
# 26    male        group E            some high school      standard
# 30    male        group E                 high school      standard
# ..     ...            ...                         ...           ...
# 401   male        group C                 high school      standard
# 403   male        group B                 high school      standard
# 406   male        group D                some college  free/reduced
# 407   male        group C                 high school      standard
# 408   male        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 15                     none          97             93             91
# ...

# %%
df[(df.gender == 'male') & (df['test preparation course'] == 'none') & (df['math score'] >= 70)]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 15    male        group C          associate's degree      standard
# 17    male        group E                some college      standard
# 23    male        group D             master's degree      standard
# 26    male        group E            some high school      standard
# 30    male        group E                 high school      standard
# ..     ...            ...                         ...           ...
# 401   male        group C                 high school      standard
# 403   male        group B                 high school      standard
# 406   male        group D                some college  free/reduced
# 407   male        group C                 high school      standard
# 408   male        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score  \
# 15                     none          97             93             91
# ...

# %%
df.loc[(df.gender == 'male') & (df['test preparation course'] == 'completed') & (df['math score'] >= 65)]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1     male        group E           bachelor's degree      standard
# 3     male        group E          associate's degree  free/reduced
# 4     male        group D                some college      standard
# 5     male        group A                some college      standard
# 9     male        group E                some college      standard
# ..     ...            ...                         ...           ...
# 528   male        group D                some college      standard
# 537   male        group C          associate's degree  free/reduced
# 544   male        group C          associate's degree  free/reduced
# 546   male        group B            some high school      standard
# 547   male        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# 1                 completed         100            100            100
# ...

# %%
#Agrupamento - agrupa os dados por gênero e obtém estatísticas descritivas
df.groupby(by = 'gender')[provas].agg([np.mean, np.median]).T
# Out:
# /var/folders/99/f7vrg9j95l983qz2dfym8b1m0000gn/T/ipykernel_16267/1477469013.py:2: FutureWarning: The provided callable <function mean at 0x106b54540> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(by = 'gender')[provas].agg([np.mean, np.median]).T
# /var/folders/99/f7vrg9j95l983qz2dfym8b1m0000gn/T/ipykernel_16267/1477469013.py:2: FutureWarning: The provided callable <function median at 0x106d9b6a0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df.groupby(by = 'gender')[provas].agg([np.mean, np.median]).T
# ...
